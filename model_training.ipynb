# %% [markdown]
# # Antrenam un model de la zero folosind datele colectate

# %%
# Morariu Tudor

import pandas as pd

data_articulatii = pd.read_csv("date_energie/date_miscare_articulatii/date_interp_articulatii.csv");
data_multiple = pd.read_csv("date_energie/date_multiple/date_interp_07_10_2024.csv");
data_patrat = pd.read_csv("date_energie/date_patrat/date_interp_patrat.csv");
data_triunghi = pd.read_csv("date_energie/date_triunghi/date_interp_triunghi.csv");

# %%
def preprocess(data):
    data.dropna(inplace=True);


    # Adaug media pe J(1...6), V(1...6), A(1...6) pentru niste feature engeneering

    data["J_avg"] = (data['J1'] + data['J2'] + data['J3'] + data['J4'] + data['J5'] + data['J6']) / 6; 
    data["V_avg"] = (data['V1'] + data['V2'] + data['V3'] + data['V4'] + data['V5'] + data['V6']) / 6;
    data["A_avg"] = (data['A1'] + data['A2'] + data['A3'] + data['A4'] + data['A5'] + data['A6']) / 6;
    

    # Elimin coloana de timp pentru ca nu ofera date semnificative modelului

    data.drop(columns="Time", inplace=True);
    

    return data;



data_multiple = preprocess(data_multiple);
data_patrat = preprocess(data_patrat);
data_triunghi = preprocess(data_triunghi);

# %%
# Concatenez toate datele intr-un DataFrame
# Nu folosesc data_articulatii pentru ca labelul ("Power") are niste valori foarte diferite fata de cele din celelalte 3 seturi de date.
all_data = pd.concat([data_multiple, data_patrat, data_triunghi])

# %%
from sklearn.utils import shuffle

# Amestec datele ca sa nu apara ceva patern-uri nedorite 

all_data = shuffle(all_data)

# %%
import pandas as pd
import numpy as np

# Plotez o matrice de corelatie
rs = np.random.RandomState(0)
corr = all_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_97dea_row0_col0, #T_97dea_row0_col5, #T_97dea_row0_col19, #T_97dea_row1_col1, #T_97dea_row2_col2, #T_97dea_row3_col3, #T_97dea_row4_col4, #T_97dea_row5_col0, #T_97dea_row5_col5, #T_97dea_row5_col19, #T_97dea_row6_col6, #T_97dea_row6_col11, #T_97dea_row6_col20, #T_97dea_row7_col7, #T_97dea_row8_col8, #T_97dea_row9_col9, #T_97dea_row10_col10, #T_97dea_row11_col6, #T_97dea_row11_col11, #T_97dea_row11_col20, #T_97dea_row12_col12, #T_97dea_row12_col17, #T_97dea_row12_col21, #T_97dea_row13_col13, #T_97dea_row14_col14, #T_97dea_row15_col15, #T_97dea_row16_col16, #T_97dea_row17_col12, #T_97dea_row17_col17, #T_97dea_row17_col21, #T_97dea_row18_col18, #T_97dea_row19_col0, #T_97dea_row19_col5, #T_97dea_row19_col19, #T_97dea_row20_col6, #T_97dea_row20_col11, #T_97dea_row20_col20, #T_97dea_row21_col12, #T_97dea_row21_col17, #T_97dea_row21_col21 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_97dea_row0_col1, #T_97dea_row0_col14, #T_97dea_row3_col13, #T_97dea_row5_col14, #T_97dea_row6_col14, #T_97dea_row9_col13, #T_97dea_row12_col7, #T_97dea_row17_col7, #T_97dea_row18_col14, #T_97dea_row19_col14, #T_97dea_row21_col7 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_97dea_row0_col2, #T_97dea_row1_col14, #T_97dea_row2_col13, #T_97dea_row10_col16, #T_97dea_row13_col2, #T_97dea_row13_col4, #T_97dea_row14_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_97dea_row0_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_97dea_row0_col4, #T_97dea_row2_col14, #T_97dea_row14_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_97dea_row0_col6, #T_97dea_row0_col11, #T_97dea_row0_col20, #T_97dea_row1_col0, #T_97dea_row5_col6, #T_97dea_row5_col11, #T_97dea_row5_col20, #T_97dea_row6_col12, #T_97dea_row6_col17, #T_97dea_row6_col21, #T_97dea_row8_col6, #T_97dea_row8_col11, #T_97dea_row8_col20, #T_97dea_row11_col12, #T_97dea_row11_col17, #T_97dea_row11_col21, #T_97dea_row13_col20, #T_97dea_row14_col0, #T_97dea_row14_col5, #T_97dea_row14_col19, #T_97dea_row15_col0, #T_97dea_row15_col5, #T_97dea_row15_col6, #T_97dea_row15_col11, #T_97dea_row15_col19, #T_97dea_row15_col20, #T_97dea_row16_col6, #T_97dea_row16_col11, #T_97dea_row16_col20, #T_97dea_row19_col6, #T_97dea_row19_col11, #T_97dea_row19_col20, #T_97dea_row20_col12, #T_97dea_row20_col17, #T_97dea_row20_col21 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_97dea_row0_col7, #T_97dea_row5_col7, #T_97dea_row19_col7 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_97dea_row0_col8, #T_97dea_row5_col8, #T_97dea_row19_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_97dea_row0_col9, #T_97dea_row3_col6, #T_97dea_row3_col11, #T_97dea_row3_col20, #T_97dea_row5_col9, #T_97dea_row16_col14, #T_97dea_row18_col3, #T_97dea_row19_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_97dea_row0_col10, #T_97dea_row1_col16, #T_97dea_row5_col10, #T_97dea_row9_col10, #T_97dea_row12_col10, #T_97dea_row14_col4, #T_97dea_row17_col10, #T_97dea_row19_col10, #T_97dea_row21_col10 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_97dea_row0_col12, #T_97dea_row0_col17, #T_97dea_row0_col21, #T_97dea_row1_col2, #T_97dea_row1_col6, #T_97dea_row1_col11, #T_97dea_row1_col20, #T_97dea_row2_col1, #T_97dea_row2_col4, #T_97dea_row3_col15, #T_97dea_row5_col12, #T_97dea_row5_col17, #T_97dea_row5_col21, #T_97dea_row7_col10, #T_97dea_row7_col18, #T_97dea_row8_col0, #T_97dea_row8_col5, #T_97dea_row8_col9, #T_97dea_row8_col19, #T_97dea_row10_col7, #T_97dea_row10_col8, #T_97dea_row13_col14, #T_97dea_row14_col13, #T_97dea_row14_col16, #T_97dea_row15_col3, #T_97dea_row19_col12, #T_97dea_row19_col17, #T_97dea_row19_col21 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_97dea_row0_col13, #T_97dea_row2_col16, #T_97dea_row3_col14, #T_97dea_row5_col13, #T_97dea_row6_col13, #T_97dea_row7_col1, #T_97dea_row8_col2, #T_97dea_row9_col2, #T_97dea_row11_col13, #T_97dea_row12_col2, #T_97dea_row15_col1, #T_97dea_row15_col2, #T_97dea_row15_col13, #T_97dea_row17_col2, #T_97dea_row19_col1, #T_97dea_row19_col13, #T_97dea_row20_col13, #T_97dea_row21_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_97dea_row0_col15, #T_97dea_row1_col15, #T_97dea_row2_col15, #T_97dea_row4_col15, #T_97dea_row5_col15, #T_97dea_row7_col15, #T_97dea_row10_col15, #T_97dea_row13_col15, #T_97dea_row18_col15, #T_97dea_row19_col15 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_97dea_row0_col16, #T_97dea_row3_col16, #T_97dea_row5_col16, #T_97dea_row6_col8, #T_97dea_row7_col14, #T_97dea_row11_col8, #T_97dea_row15_col14, #T_97dea_row19_col16, #T_97dea_row20_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_97dea_row0_col18, #T_97dea_row2_col5, #T_97dea_row9_col0, #T_97dea_row9_col5, #T_97dea_row9_col6, #T_97dea_row9_col19, #T_97dea_row9_col20 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_97dea_row1_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_97dea_row1_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_97dea_row1_col5, #T_97dea_row1_col18, #T_97dea_row1_col19, #T_97dea_row6_col0, #T_97dea_row6_col5, #T_97dea_row6_col19, #T_97dea_row9_col3, #T_97dea_row11_col0, #T_97dea_row11_col5, #T_97dea_row11_col19, #T_97dea_row13_col0, #T_97dea_row13_col5, #T_97dea_row13_col19, #T_97dea_row20_col0, #T_97dea_row20_col5, #T_97dea_row20_col19 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_97dea_row1_col7, #T_97dea_row4_col10, #T_97dea_row5_col1, #T_97dea_row9_col1, #T_97dea_row9_col7, #T_97dea_row12_col1, #T_97dea_row15_col7, #T_97dea_row15_col10, #T_97dea_row15_col16, #T_97dea_row17_col1, #T_97dea_row21_col1 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_97dea_row1_col8 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_97dea_row1_col9, #T_97dea_row2_col9, #T_97dea_row4_col2, #T_97dea_row7_col9, #T_97dea_row12_col9, #T_97dea_row17_col9, #T_97dea_row21_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_97dea_row1_col10, #T_97dea_row2_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_97dea_row1_col12, #T_97dea_row1_col17, #T_97dea_row1_col21, #T_97dea_row8_col12, #T_97dea_row8_col17, #T_97dea_row8_col21, #T_97dea_row9_col12, #T_97dea_row9_col17, #T_97dea_row9_col21, #T_97dea_row10_col12, #T_97dea_row10_col17, #T_97dea_row10_col21, #T_97dea_row18_col12, #T_97dea_row18_col17, #T_97dea_row18_col21 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_97dea_row1_col13, #T_97dea_row2_col10, #T_97dea_row3_col8, #T_97dea_row6_col7, #T_97dea_row11_col7, #T_97dea_row13_col1, #T_97dea_row20_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_97dea_row2_col0, #T_97dea_row10_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_97dea_row2_col3, #T_97dea_row18_col7 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_97dea_row2_col6, #T_97dea_row2_col11, #T_97dea_row2_col20, #T_97dea_row7_col0, #T_97dea_row7_col5, #T_97dea_row7_col19 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_97dea_row2_col8, #T_97dea_row3_col4, #T_97dea_row12_col8, #T_97dea_row17_col8, #T_97dea_row21_col8 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_97dea_row2_col12, #T_97dea_row2_col17, #T_97dea_row2_col21, #T_97dea_row13_col16, #T_97dea_row14_col15 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_97dea_row2_col18 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_97dea_row2_col19, #T_97dea_row5_col18, #T_97dea_row12_col15, #T_97dea_row16_col15, #T_97dea_row17_col15, #T_97dea_row19_col18, #T_97dea_row21_col15 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_97dea_row3_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_97dea_row3_col1, #T_97dea_row8_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_97dea_row3_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_97dea_row3_col5 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_97dea_row3_col7, #T_97dea_row9_col16, #T_97dea_row10_col14, #T_97dea_row12_col14, #T_97dea_row13_col10, #T_97dea_row15_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_97dea_row3_col9 {
#   background-col

# %%
all_X = all_data.drop(columns="Power");
all_y = all_data["Power"];

# %%
from sklearn.decomposition import PCA 
import matplotlib.pyplot as plt

# Fac un plot folosind PCA(algoritm de reducerea dimensiuniilor)
# Setez culoarea la ce valoare trebuie sa prezicem (culoare mai aprinsa daca "power" este mai mare si invers)

plt.style.use("dark_background");

points = PCA(n_components=2).fit_transform(all_X, all_y);

plt.figure(figsize=(12, 12), dpi = 80)
plt.scatter(points[:, 0], points[:, 1], c=all_y, marker='.')

# %%
from sklearn.model_selection import train_test_split

# Selectez date de train/test

test_X = all_X[-500:]
test_y = all_y[-500:]

train_X = all_X[:-500]
train_y = all_y[:-500]

# %%
import catboost
import xgboost
import lightgbm

from sklearn.ensemble import VotingRegressor

# Folosesc hiperparametrii sandard, pot fi imbunatatiti cu optuna.
# Folosesc un VotingRegressor care face media pe predictiile primite de la fiecare model. In teorie va avea o generalizare mai buna.

cat = catboost.CatBoostRegressor(n_estimators=500, max_depth=8);
xgb = xgboost.XGBRegressor(n_estimators=500, max_depth=8);
lgb = lightgbm.LGBMRegressor(n_estimators=500, max_depth=8);

model = VotingRegressor([("cat", cat), ("xgb", xgb), ("lgb", lgb)]);
model.fit(train_X, train_y)

# %%
import pickle

# Salvez modelul intr-un pikle pentru al untiliza mai tarziu
with open('model.pkl','wb') as f:
    pickle.dump(model,f)

# %%
predictii = model.predict(test_X)

# %%
from sklearn.metrics import *

print("------ Model Metrics ------\n")
print("R2 Score:", r2_score(test_y, model.predict(test_X)))
print("Mean Squared Error:", mean_squared_error(test_y, model.predict(test_X)))
print("Mean Absolute Error:", mean_absolute_error(test_y, model.predict(test_X)))
print("Root Mean Squared Error:", root_mean_squared_error(test_y, model.predict(test_X)))
print("\n---------------------------")
# Out:
# ------ Model Metrics ------
#
# R2 Score: 0.9360867704158122
# Mean Squared Error: 5.886118169302909e-05
# Mean Absolute Error: 0.0048933773111255515
# Root Mean Squared Error: 0.007672104124230137
#
# ---------------------------

# %%
import matplotlib.pyplot as plt

ax = plt.figure(figsize=(20, 10)).subplots(2, 2, gridspec_kw={'width_ratios': [1, 1]})
plt.subplots_adjust(wspace=0, hspace=0)

ax[0][0].set_ylim(ymin=0.2, ymax=0.6)
ax[0][1].set_ylim(ymin=0.2, ymax=0.6)

ax[0][0].set_facecolor('xkcd:lightblue')
ax[1][0].set_facecolor('xkcd:lightblue')
ax[0][1].set_facecolor('xkcd:salmon')
ax[1][1].set_facecolor('xkcd:lightgreen')

ax[0][1].set_xticks([])
ax[0][1].set_yticks([])

set_off_for_train = 1000;


ax[0][0].plot(range(len(train_y[:set_off_for_train])), train_y[:set_off_for_train])
ax[0][0].legend(("labels"))

ax[1][0].plot(range(len(train_X[:set_off_for_train])), train_X[["J_avg", "V_avg", "A_avg"]][:set_off_for_train])
ax[1][0].legend(("J avrage", "V avrage", "A avrage"))


ax[0][1].plot(range(len(test_y)), test_y)
ax[0][1].plot(range(len(test_X)), predictii, c="r", alpha=0.35)
ax[0][1].legend(("expected", "predicted"))

ax[1][1].plot(range(len(test_X)), test_X[["J_avg", "V_avg", "A_avg"]])
ax[1][1].legend(("J avrage", "V avrage", "A avrage"), loc='upper left')
ax[1][1].set_yticks([])
# Out:
# []
